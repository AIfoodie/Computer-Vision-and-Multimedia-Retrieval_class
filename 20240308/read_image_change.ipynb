# %%
# read and plot image on figure
import matplotlib.pyplot as plt
import cv2
# Python program to read and write (save) an image (in another form)

#import imageio as iio
 
# read an image 

image = cv2.imread("earth.tiff")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #試一下少這個指令的執行結果
plt.figure()
plt.imshow(image)
plt.show()

# %% [markdown]
#                         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #試一下少這個指令的執行結果
# ![image.png](attachment:image.png)

# %%
# read and plot image on figure
import matplotlib.pyplot as plt
import cv2
image = cv2.imread("lena_color.jpg")
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #試一下少這個指令的執行結果
plt.figure()
plt.imshow(image)
plt.show()

# %%
# read and plot image on figure
import matplotlib.pyplot as plt
import cv2
image = cv2.imread("lena_color.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #試一下少這個指令的執行結果
plt.figure()
plt.imshow(image)
plt.show()

# %%
# read and plot image on figure
import matplotlib.pyplot as plt
import cv2
image = cv2.imread("bitplane.jpg")
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(image)
#plt.imshow(image, 'gray')
plt.show()

# %%
# Python program to read and write (save) an image (in another form)

import imageio as iio
 
# read an image 
image = iio.imread("lena_color.jpg")
 
# write it in a new format
iio.imwrite("lena_color.png", image)

# %%
# Python program to read image using OpenCV
# read and show image on window 
# importing OpenCV(cv2) module
import cv2
 
# Save image in set directory
# Read RGB image
image = cv2.imread("lena_color.jpg") 
 
# Output img with window name as 'image'
cv2.imshow('image', image) 
 
# Maintain output window until
# user presses a key
cv2.waitKey(0)        

# Destroying present windows on screen
cv2.destroyAllWindows()

# %%
#https://blog.csdn.net/hhy0907/article/details/123440498
import matplotlib.pyplot as plt
import cv2
# Python program to read and write (save) an image (in another form)

#import imageio as iio
 
# read an image 

image = cv2.imread("earth.tiff")
B, G, R =cv2.split(image)


plt.figure()
plt.imshow(B,)
plt.show() 

plt.figure()
plt.imshow(G, 'gray')
plt.show() 

plt.figure()
plt.imshow(R, 'gray')
plt.show()
